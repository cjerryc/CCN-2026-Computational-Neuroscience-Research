# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/connections_princeton_no_threshold.csv"
df = pd.read_csv(file_path)

# %% [markdown]
# ### Versioning:

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.0.2

# %% [markdown]
# Each row contains:
# -----------------------------------------------
# * **pre_pt_root_id**: (presynaptic neuron ID)
# * **post_pt_root_id**: (postsynaptic neuron ID)
# * **neuropil**: (brain region)
# * **nt_type**: (Neurotransmitter type) This field labels the predicted neurotransmitter for each synaptic connection (e.g., acetylcholine, GABA, glutamate, etc.)
# * **syn_count**: number of synapses between this specific pre-post pair in that neuropil
#
# So in Codex's neuropils view:
# --------------------------------
# * Each row corresponds to a directed connection between two neurons within one neuropil.
# * syn_count: How many synaptic contact points define that edge. Defines strong vs. weak connections.
# * Example: A syn_count of 7 means neuron X makes 7 synapses onto neuron Y within the specified neuropil.

# %%
df.size
# Out:
# 113487205

# %%
df.head()
# Out:
#        pre_pt_root_id     post_pt_root_id neuropil  syn_count nt_type
# 0  720575940613354467  720575940616690107     ME_L          1     ACH
# 1  720575940625363947  720575940623224444     ME_L         13    GABA
# 2  720575940630432382  720575940618518557     ME_L         71     ACH
# 3  720575940627314521  720575940626337738     ME_L         10     NaN
# 4  720575940616775218  720575940632128018     ME_L          1     ACH

# %%
df["pre_pt_root_id"].nunique()
# Out:
# 139028

# %%
df["post_pt_root_id"].nunique()
# Out:
# 138998

# %% [markdown]
# ## Neuropil Exploration

# %%
# The regions of the brain
# Refers to the brain region where a synapse connects. In flies, brain regions are divided into neuropils—bundled fiber areas like the antennal lobe (AL),
# medulla (ME), lobula (LO), mushroom body (MB), central complex, etc.
# In Codex, each synapse edge reports the neuropil (region) in which it's found. Edges may span different neuropils, and are grouped by region in the graph.
# https://codex.flywire.ai/app/neuropils?dataset=fafb

df["neuropil"].unique()
# Out:
# array(['ME_L', 'LA_L', nan, 'LOP_L', 'LO_L', 'PVLP_L', 'AVLP_L', 'AOTU_L',
#        'AME_L', 'SLP_L', 'LH_L', 'PLP_L', 'SLP_R', 'AVLP_R', 'LO_R',
#        'ICL_L', 'SMP_R', 'ME_R', 'GNG', 'AMMC_L', 'SMP_L', 'AL_R',
#        'IPS_L', 'LAL_R', 'ICL_R', 'WED_R', 'IPS_R', 'MB_VL_R', 'AMMC_R',
#        'SAD', 'MB_PED_R', 'LOP_R', 'SPS_L', 'CRE_R', 'VES_L', 'FB',
#        'MB_ML_R', 'VES_R', 'MB_ML_L', 'FLA_L', 'PVLP_R', 'LAL_L', 'EPA_R',
#        'GOR_R', 'SCL_R', 'CRE_L', 'MB_PED_L', 'AME_R', 'PLP_R', 'AL_L',
#        'WED_L', 'IB_L', 'MB_VL_L', 'SIP_L', 'SPS_R', 'LH_R', 'PB',
#        'ATL_L', 'PRW', 'SCL_L', 'CAN_R', 'LA_R', 'SIP_R', 'MB_CA_L',
#        'IB_R', 'MB_CA_R', 'EPA_L', 'FLA_R', 'EB', 'BU_R', 'AOTU_R',
#        'GOR_L', 'NO', 'ATL_R', 'CAN_L', 'GA_L', 'BU_L', 'OCG', 'GA_R'],
#       dtype=object)

# %%
df_long = pd.melt(df, id_vars="neuropil", value_vars=["pre_pt_root_id", "post_pt_root_id"],
                  var_name="role", value_name="pt_root_id")

unique_ids_per_neuropil = df_long.groupby("neuropil")["pt_root_id"].nunique().sort_values()
unique_ids_per_neuropil
# Out:
# neuropil
# OCG        409
# BU_L       473
# GA_R       623
# BU_R       653
# CAN_L      680
#          ...
# LOP_L    21057
# LO_R     24517
# LO_L     25031
# ME_R     37310
# ME_L     37364
# Name: pt_root_id, Length: 78, dtype: int64

# %% [markdown]
# ## Start with **Smallest** brain regions.
#
#
#
# 1.   LH_L (5723)
# 2.   OCG (409)

# %%
df_LH_L = df[df["neuropil"]=='LH_L']
df_LH_L.head()
# Out:
#             pre_pt_root_id     post_pt_root_id neuropil  syn_count nt_type
# 381996  720575940608199748  720575940634026925     LH_L          7     ACH
# 382014  720575940628200506  720575940635515572     LH_L          3     ACH
# 382041  720575940627035388  720575940641562587     LH_L          5     ACH
# 382043  720575940637297271  720575940626985253     LH_L          1     NaN
# 382069  720575940635468991  720575940631172748     LH_L          3    GABA

# %%
# In a directed graph adjacency matrix, the row that represents node '720575940608199748' will have 277 nonzero entries.
df_LH_L[df_LH_L['pre_pt_root_id'] == 720575940608199748]
# Out:
#               pre_pt_root_id     post_pt_root_id neuropil  syn_count nt_type
# 381996    720575940608199748  720575940634026925     LH_L          7     ACH
# 415445    720575940608199748  720575940608971221     LH_L          4     ACH
# 482011    720575940608199748  720575940631880505     LH_L          5     ACH
# 515240    720575940608199748  720575940640883363     LH_L          2     ACH
# 520695    720575940608199748  720575940616032406     LH_L          2     ACH
# ...                      ...                 ...      ...        ...     ...
# 21603714  720575940608199748  720575940622674712     LH_L          5     ACH
# 21613093  720575940608199748  720575940605877728     LH_L          2     ACH
# 21619506  720575940608199748  720575940612921581     LH_L          6     ACH
# 21621904  720575940608199748  720575940630281580     LH_L          2     ACH
# 21648547  720575940608199748  720575940620676312     LH_L          1     ACH
#
# [277 rows x 5 columns]

# %%
# Number of edges/connections in LH_L brain region.
df_LH_L.size
# Out:
# 1372190

# %%
# Number of unique nodes in the LH_L brain region.

# Get unique pre and post node IDs separately
pre_nodes = df_LH_L['pre_pt_root_id'].unique()
post_nodes = df_LH_L['post_pt_root_id'].unique()

# Use set union (mask-based logic)
unique_nodes = set(pre_nodes) | set(post_nodes)

# Count total unique nodes
num_unique_nodes = len(unique_nodes)

print("Total unique nodes:", num_unique_nodes)
# Out:
# Total unique nodes: 5723

# %%
# unique pre nodes in LH_L
df_LH_L["pre_pt_root_id"].nunique()
# Out:
# 4990

# %%
# unique post nodes in LH_L
df_LH_L["post_pt_root_id"].nunique()
# Out:
# 5444

# %% [markdown]
# ## Create an adjacency graph of the LH_L subgraph connections.
# (binary, unweighted)
#
# *   adj_sparse: CSR sparse adjacency matrix (0/1 entries)
# *   node_to_idx: Mapping from neuron ID --> matrix row/col index

# %%
import pandas as pd
import numpy as np
from scipy.sparse import coo_matrix

def compute_adj_sparse_mat(df_subgraph, directed=False):
  # Get all unique node IDs
  nodes = pd.unique(df_subgraph[['pre_pt_root_id', 'post_pt_root_id']].values.ravel())
  node_to_idx = {node: i for i, node in enumerate(nodes)}

  # Map each ID to its index
  row = df_subgraph['pre_pt_root_id'].map(node_to_idx).values
  col = df_subgraph['post_pt_root_id'].map(node_to_idx).values

  # # Use syn_count as the weight for each edge?
  # data = df_subgraph['syn_count'].values>

  # Use binary weights: 1 for each edge
  data = np.ones_like(row, dtype=int)

  # Build sparse adjacency matrix (directed by default)
  n = len(nodes)
  adj_sparse = coo_matrix((data, (row, col)), shape=(n, n)).tocsr()

  # To make the graph UNDIRECTED:
  if not directed:
    adj_sparse = adj_sparse + adj_sparse.T
    adj_sparse.data[:] = 1  # Ensure it's still binary (not 2s)

  return adj_sparse, node_to_idx

# %% [markdown]
# ### Compute Clustering Coefficient and Path Length

# %%
# Calculating Clustering Coeff. with directed graph

# Assuming A is a scipy sparse matrix
# Need to use a definition of directed clustering for a directed graph, such as Fagiolo's clustering coefficient:
# For directed graphs, we need to count directed triangles considering edge directions.
import numpy as np
from scipy.sparse import issparse

def calculate_global_clustering_sparse(A, directed=False) -> float:
  if not directed:
    # # MAKE ADJ GRAPH UNDIRECTED
    A = A.maximum(A.T)  # sparse matrix max method

    A2 = A @ A
    A2_sum = A2.sum()
    A2_trace = A2.diagonal().sum()

    # Step 1: Count connected triples = sum(A²) - trace(A²)
    k = A2_sum - A2_trace

    # Step 2: Calculate Global clustering coefficient, only calculate triangles if triples is nonzero:
    if k == 0:
      return 0.0

    # Step 2.1: Triangle count = trace(A³)
    A3 = A2 @ A
    A3_trace = A3.diagonal().sum()
    return A3_trace / k

  else:
    # Directed graph clustering coefficient (Fagiolo 2007) https://arxiv.org/pdf/physics/0612169
    # Step 1: Binarize adjacency matrix so all edges count as 1.
    # Step 2: Symmetrize adjacency A_sym = A + A^T to compute combined in- and out-degrees.
    # Step 3: Compute trace(A_sym^3), counting directed triangles.
    # Step 4: Compute denominator as sum over nodes of di(di - 1) where di = in_degree + out_degree subtracting bilateral edges (A_bin[i, j] == 1 AND A_bin[j, i] == 1)
    # Step 5: Return the ratio as the global clustering coefficient for the directed graph.

    # Step 1: Convert to binary adjacency (edges = 1)
    A_bin = A.copy()
    A_bin.data[:] = 1

    # Step 2: Calculate symmetrized adjacency matrix
    A_sym = A_bin + A_bin.T

    # Step 3: Calculate numerator = trace(A^3)
    A3 = A_sym @ A_sym @ A_sym
    triangles = A3.diagonal().sum()

    # Step 4: Calculate denominator = number of possible triangles
    degrees_tot = np.array(A_sym.sum(axis=1)).flatten()  # in-degree + out-degree
    A2 = A_bin @ A_bin
    num_bilateral_edges = A2.diagonal()
    possible_triangles = 2 * ((degrees_tot * (degrees_tot - 1)) - (2 * num_bilateral_edges))

    total_possible = possible_triangles.sum()
    if total_possible == 0:
      return 0.0

    # Step 5: Global clustering coefficient
    return triangles / total_possible


# Calculating Path Length with undirected graph
# Use built in scipy.sparse.csgraph shortest path algorithms that are optimized for sparse matrices:
from scipy.sparse.csgraph import shortest_path
import numpy as np

def calculate_path_length_sparse(A, directed=False):
  # Ensure adjacency matrix is symmetric if undirected
  if not directed:
    A = A.maximum(A.T)

  # Replace zeros with inf for distances (non-edges)
  # shortest_path treats zeros as no edge by default if you pass 'unweighted=False'
  # so we can just pass the adjacency matrix directly if it encodes weights properly
  # For unweighted graph, set all edges to 1
  A.data[:] = 1

  # Compute all pairs shortest paths
  dist_matrix = shortest_path(A, directed=directed, unweighted=True)

  # Mask out infinite distances (no path)
  finite_distances = dist_matrix[np.isfinite(dist_matrix) & (dist_matrix != 0)]

  # Return average shortest path length (excluding zero distances)
  return np.mean(finite_distances)


def calculate_degree_distribution(A, directed=True):
    if not directed:
        # Make adjacency symmetric
        A = np.maximum(A, A.T)
        # Degree = sum of either rows or columns
        degree = np.sum(A, axis=0)
        return degree
    else:
        # For directed: return both in-degree and out-degree
        in_degree = np.sum(A, axis=0)   # column sums
        out_degree = np.sum(A, axis=1).T  # row sums
        return in_degree, out_degree

# %%
direct = True

# Create adj_sparse
adj_sparse, node_to_idx = compute_adj_sparse_mat(df_LH_L, directed=direct)

print("Shape:", adj_sparse.shape)
print("Edges:", adj_sparse.nnz // 2)  # Undirected, so count each edge once
print("Edge density:", adj_sparse.nnz / (adj_sparse.shape[0] ** 2))
# Out:
# Shape: (5723, 5723)
# Edges: 137219
# Edge density: 0.008379088044846583

# %%
deg_dist_IN, deg_dist_OUT = calculate_degree_distribution(adj_sparse, direct)
print("In-Degree Distribution: ", deg_dist_IN)
print("Out-Degree Distribution: ", deg_dist_OUT)
# Out:
# In-Degree Distribution:  [[66  6 62 ...  1  1  1]]
# Out-Degree Distribution:  [[277   1 299 ...   0   0   0]]

# %%
clustCoeff = calculate_global_clustering_sparse(adj_sparse, directed=direct)
print("Clustering Coefficient: ", clustCoeff)
# Out:
# Clustering Coefficient:  0.15081902392701466

# %%
characteristic_path_length = calculate_path_length_sparse(adj_sparse, directed=direct)
print("Characteristic Path Length:", characteristic_path_length)
# Out:
# Characteristic Path Length: 3.45513855466384

# %% [markdown]
# #### Find the average degree of the graph (directed / undirected)

# %%
# Assume A is a sparse adjacency matrix (CSR format)
# Directed graph: row sums = out-degree, col sums = in-degree
def compute_graph_average_degree(A, directed=False):
  if directed:
    total_in_deg = A.sum(axis=0).A1.sum()
    total_out_deg = A.sum(axis=1).A1.sum()
    # These should be equal for any directed graph
    assert total_in_deg == total_out_deg

    avg_total_degree_d = (total_in_deg + total_out_deg) / A.shape[0]
    # Check the average total degrees of a node to be within bounds
    # Since the sum of in-degrees equals the sum of out-degrees in a directed graph (each edge contributes one to each), we are effectively computing:
    # avg_total_degree = 2 * total_edges / n
    assert avg_total_degree_d <= 2 * (A.shape[0] - 1)

    return avg_total_degree_d

  else:
    # Undirected
    degrees = A.sum(axis=1)  # or axis=0
    avg_degree = degrees.mean()
    return avg_degree

# %%
# Compute Directed average degree of graph
print("Average Degree:", compute_graph_average_degree(adj_sparse, directed=direct))
# Out:
# Average Degree: 95.90704176131399

# %% [markdown]
# # Perform calculations of Random G(n,p) Graphs
#
# *   Clustering Coefficient
# *   Path Length
# *   Small-World Calculation thresholding

# %% [markdown]
# ## Generate a Random GNP graph

# %% [markdown]
# ### SPARSE ADJ GRAPH REPRESENTATION

# %%
import numpy as np
from scipy.sparse import coo_matrix, csr_matrix

def create_sparse_adj_graph(n, p, direct=False, seed=None):
  rng = np.random.default_rng(seed)

  # Total possible edges (upper triangle only for undirected)
  if direct:
    num_possible = n * (n - 1)
    triu_rows, triu_cols = np.where(np.ones((n, n)) - np.eye(n))
  else:
    triu_rows, triu_cols = np.triu_indices(n, k=1)
    num_possible = len(triu_rows)

  # Randomly sample which edges to include
  mask = rng.random(num_possible) < p
  rows = triu_rows[mask]
  cols = triu_cols[mask]

  # Undirected: add symmetric edges
  if not direct:
    rows = np.concatenate([rows, cols])
    cols = np.concatenate([cols, rows[:len(cols)]])

  data = np.ones_like(rows)
  A = coo_matrix((data, (rows, cols)), shape=(n, n))
  return A.tocsr()

# %% [markdown]
# ## Create an Adjacency Matrix of a random Gnp Graph

# %% [markdown]
# To generate a G(n, p) (Erdos-Renyi) graph with a desired average degree **d**, we may compute the edge probability **p** as :
#
# #### UNDIRECTED GRAPH
# **p = d / (n-1)**
#
# In a G(n, p) graph:
#
# Each possible edge exists independently with probability **p**
#
# For undirected graphs, the expected degree of a node is:
#
# E[d] = p * (n-1):
#
# #### DIRECTED GRAPH
# For a directed graph, each node can expect:
#
#
# 1.   **in-degree = p * (n - 1)**
# 2.   **out-degree = p * (n - 1)**
#
# Thus, the expected **total-degree** of a node is:
#
# **E[d] = 2p(n - 1)**
#
# So, p = d / 2(n - 1)

# %%
# direct = Directed Boolean
# n = Number of nodes
# d = degree of biological graph (drosophila)
# p = Edge probability

def compute_p(n, d, directed):
  if directed:
    return d / (2 * (n - 1))
  else:
    return d / (n - 1)

# %%
direct = True
n = 5723
d = 96
p = compute_p(n, d, directed=direct)

adj = create_sparse_adj_graph(n, p, direct)
print("Shape:", adj.shape)
print("Edges:", adj.nnz // 2)  # Undirected, so count each edge once
print("Edge density:", adj.nnz / (adj.shape[0] ** 2))
# Out:
# Shape: (5723, 5723)
# Edges: 137164
# Edge density: 0.008375760077885418

# %% [markdown]
# ## Compute the Clustering Coefficient and Characteristic Path Length of the Random Gnp Graph.

# %%
clustCoeff_rand_LHL = calculate_global_clustering_sparse(adj, directed=direct)
print("Clustering Coefficient: ", clustCoeff_rand_LHL)
# Out:
# Clustering Coefficient:  0.00833664523848189

# %%
characteristic_path_length_rand_LHL = calculate_path_length_sparse(adj, directed=direct)
print("Characteristic Path Length:", characteristic_path_length_rand_LHL)
# Out:
# Characteristic Path Length: 2.655404252834595

# %% [markdown]
# ## OCG calculation

# %%
direct_OCG = True
n_OCG = 409
d_OCG = 25
p_OCG = compute_p(n_OCG, d_OCG, directed=direct_OCG)

adj_OCG = create_sparse_adj_graph(n_OCG, p_OCG, direct_OCG)
print("Shape:", adj_OCG.shape)
print("Edges:", adj_OCG.nnz // 2)  # Undirected, so count each edge once
print("Edge density:", adj_OCG.nnz / (adj_OCG.shape[0] ** 2))
# Out:
# Shape: (409, 409)
# Edges: 2568
# Edge density: 0.030702829370938718

# %%
clustCoeff_rand_OCG = calculate_global_clustering_sparse(adj_OCG, directed=direct_OCG)
print("Clustering Coefficient: ", clustCoeff_rand_OCG)
# Out:
# Clustering Coefficient:  0.031095513478220316

# %%
characteristic_path_length_rand_OCG = calculate_path_length_sparse(adj_OCG, directed=direct_OCG)
print("Characteristic Path Length:", characteristic_path_length_rand_OCG)
# Out:
# Characteristic Path Length: 2.6524222158300974

# %% [markdown]
# ## Watts_Strogatz Graph Calculation

# %%
direct_WS_OCG = True
n_WS_OCG = 385
d_WS_OCG = 12
p_WS_OCG = compute_p(n_WS_OCG, d_WS_OCG, directed=direct_WS_OCG)

adj_WS_OCG = create_sparse_adj_graph(n_WS_OCG, p_WS_OCG, direct_WS_OCG)
print("Shape:", adj_WS_OCG.shape)
print("Edges:", adj_WS_OCG.nnz // 2)  # Undirected, so count each edge once
print("Edge density:", adj_WS_OCG.nnz / (adj_WS_OCG.shape[0] ** 2))
# Out:
# Shape: (385, 385)
# Edges: 1119
# Edge density: 0.015105414066453028

# %%
clustCoeff_WS_OCG = calculate_global_clustering_sparse(adj_WS_OCG, directed=direct_WS_OCG)
print("Clustering Coefficient: ", clustCoeff_WS_OCG)
# Out:
# Clustering Coefficient:  0.015730598927988813

# %%
characteristic_path_length_WS_OCG = calculate_path_length_sparse(adj_WS_OCG, directed=direct_WS_OCG)
print("Characteristic Path Length:", characteristic_path_length_WS_OCG)
# Out:
# Characteristic Path Length: 3.589833550913838

# %% [markdown]
# ### Compute Small-World Threshold

# %%
def compute_small_world_threshold(C_g, L_g, C_rand, L_rand):
  return (C_g / C_rand) / (L_g / L_rand)

# %%
# import C_rand, L_rand values from randGraph.ipynb
C_rand = 0.008435302420417078
L_rand = 2.6529490970869216
sigma = compute_small_world_threshold(clustCoeff, characteristic_path_length, C_rand, L_rand)
print(sigma)

if sigma > 1:
  print("Small world found!")
else:
  print("Not a small world...")
# Out:
# 13.728368173613447
# Small world found!

# %% [markdown]
# Through the small-world threshold calculation performed above on the LH_L region of the Drosophila brain, we may see that it is a small-world graph. This is defined by a high clustering coefficient and a low characteristic path length, as compared to a random GNP graph with the same number of nodes and average degree as the measured biological subgraph LH_L.

# %% [markdown]
# ## OCG Brain Region Calculation

# %%
###### OCG #########
df_OCG = df[df["neuropil"]=='OCG']
direct_OCG = True

# Create Sparse Adj Matrix
adj_sparse_OCG, node_to_idx_OCG = compute_adj_sparse_mat(df_OCG, directed=direct_OCG)

deg_dist_OCG_IN, deg_dist_OCG_OUT = calculate_degree_distribution(adj_sparse_OCG, direct_OCG)
print("In-Degree Distribution: ", np.mean(deg_dist_OCG_IN))
print("Out-Degree Distribution: ", np.mean(deg_dist_OCG_OUT))

# Compute Clustering Coefficient
clustCoeff_OCG = calculate_global_clustering_sparse(adj_sparse_OCG, directed=direct_OCG)
print("Clustering Coefficient: ", clustCoeff_OCG)

# Compute Characteristic Path Length
characteristic_path_length_OCG = calculate_path_length_sparse(adj_sparse_OCG, directed=direct_OCG)
print("Path Length: ", characteristic_path_length_OCG)

graph_average_degree_OCG = compute_graph_average_degree(adj_sparse_OCG, directed=direct_OCG)
# Compute Average Degree of Graph
print("Average Degree of Graph:", graph_average_degree_OCG)
# Out:
# In-Degree Distribution:  12.056234718826406
# Out-Degree Distribution:  12.056234718826406
# Clustering Coefficient:  0.15232445907696682
# Path Length:  2.5156683510615165
# Average Degree of Graph: 24.112469437652813

# %%
###### OCG #########

# import C_rand, L_rand values from randGraph.ipynb
C_rand_OCG = 0.030600189035916825
L_rand_OCG = 2.6501989548875784
sigma_OCG = compute_small_world_threshold(clustCoeff_OCG, characteristic_path_length_OCG, C_rand_OCG, L_rand_OCG)
print(sigma_OCG)

if sigma_OCG > 1:
  print("Small world found!")
else:
  print("Not a small world...")
# Out:
# 5.244095928485776
# Small world found!

# %% [markdown]
# #### nt_type Exploration

# %%
# Neurotransmitter type: This field labels the predicted neurotransmitter for each synaptic connection (e.g., acetylcholine, GABA, glutamate, etc.)

df["nt_type"].unique()
# Out:
# array(['ACH', 'GABA', nan, 'GLUT', 'SER', 'DA', 'OCT'], dtype=object)

# %% [markdown]
# #### **Overall connections**: Find the number of times a neuron 'pre_pt_root_id' appears in 'post_pt_root_id'

# %%
# Find the number of times a neuron 'pre_pt_root_id' appears in 'post_pt_root_id'

# Drop duplicates from 'pre_pt_root_id'
unique_col1 = df['pre_pt_root_id'].drop_duplicates()

# Count occurrences in 'post_pt_root_id'
col2_counts = df['post_pt_root_id'].value_counts()

# Map counts to the unique col1 values
result = pd.DataFrame({
    'pre_pt_root_id': unique_col1,
    'count': unique_col1.map(col2_counts).fillna(0).astype(int)
})

result.sort_values(by='count', ascending=False)
# Out:
#               pre_pt_root_id  count
# 490064    720575940624547622  15415
# 738408    720575940613583001  15213
# 739456    720575940626979621  11712
# 383140    720575940628908548  11607
# 740851    720575940620975696  10754
# ...                      ...    ...
# 16908     720575940636232555      0
# 37311     720575940628745384      0
# 90560     720575940624819975      0
# 2606565   720575940629750872      0
# 14925605  720575940614890642      0
#
# [139028 rows x 2 columns]

# %% [markdown]
# # JOIN Algorithm on Brain Region Subgraphs

# %% [markdown]
# firing_nodes = a binary vector or list of nodes currently "firing"
#
# For each node j, count how many firing nodes i have A[i, j] = 1

# %%
import numpy as np
import scipy.sparse as sp

# A: scipy.sparse matrix (n x n), A directed binary adjacency matrix.
# firing_nodes: array of indices that are currently firing
# n_nodes: number of nodes in graph
# k_s: firing threshold for the graph
# Returns: np.array of counts of firing inputs per node
# Firing from A directly to C, we should measure and allow recurrence up to 10% of mem_size.
def count_firing_inputs(A, firing_nodes, k_s, n_nodes=None):
  # Recurrence tolerance = 10% of mem_size
  RECURRENCE_TOLERANCE_THRESHOLD = 0.9
  if n_nodes is None:
    n_nodes = A.shape[0]

  # Create a binary firing vector (1 where node is firing)
  firing_vector = np.zeros(n_nodes, dtype=int)
  # Set the mode of these nodes to 'firing'
  firing_vector[firing_nodes] = 1

  # Compute number of firing inputs for each node (incoming edges from firing nodes)
  firing_input_counts = A.T @ firing_vector  # result is dense np.array
  firing_input_counts = np.array(firing_input_counts).flatten()

  # Threshold: fire if count >= k_s
  next_firing_nodes = np.where(firing_input_counts >= k_s)[0]

  # Removed original firing nodes to measure overlap between memA and created memC
  # If the overlap between memA and resultant memC is greater than 10%, then we remove those overlapped nodes from memC, due to recurrence.
  next_firing_nodes_without_overlap = np.setdiff1d(next_firing_nodes, firing_nodes)
  if len(next_firing_nodes) > 0 and len(next_firing_nodes_without_overlap) / len(next_firing_nodes) < RECURRENCE_TOLERANCE_THRESHOLD:
    next_firing_nodes = next_firing_nodes_without_overlap

  # Number of firing nodes that meet the threshold for child memory creation:
  num_meeting_threshold = len(next_firing_nodes)

  return next_firing_nodes, num_meeting_threshold


# k_s = median value of subgraph.syn_count
# Synapse Count in a connection represents the number of synapses in a connectio; otherwise described as
# axon-->dendrite connections.
# Here, we use the synapse count to average over the number of connections to find a median connection strength.
def compute_k_s_threshold(df_subgraph) -> int:
  return df_subgraph['syn_count'].median()

import random
# Set Global Seed
random.seed(0)
# node_to_idx_dict: Dictionary that maps pre, post node id's --> adj sparse matrix indices.
# mem_size: desired memory size
def generate_random_indices_for_memory(node_to_idx_dict, mem_size):
  upper_range_of_indices = len(node_to_idx_dict)
  memory_indices = random.sample(range(0, upper_range_of_indices), mem_size)
  return memory_indices

# %% [markdown]
# #### Compute the k_s threshold for a brain region, and simulate firing a random subset of nodes to represent Memory A. The connected nodes will also fire into Memory C if they meet the k_s threshold.

# %%
# Compute the synapse strength to find the k_s, firing threshold
k_s_LH_L = compute_k_s_threshold(df_LH_L)
print(k_s_LH_L)


# Memory A
# Grab a random subset of nodes through the node_to_idx dictionary, as represented by their indices.
memory_A_size = 100
memory_A = generate_random_indices_for_memory(node_to_idx, memory_A_size)

# Fire Memory A, and observe the number of firing nodes that create memory C. Also included: the indices of memory C.
activated_nodes, memory_C_size = count_firing_inputs(adj_sparse, memory_A, k_s_LH_L)
print("Size of Memory C: ", memory_C_size)
print("Memory C: ", activated_nodes)
# Out:
# 1.0
# Size of Memory C:  1952
# Memory C:  [   0    3    5 ... 5531 5581 5695]

# %% [markdown]
# ### Plot varying sizes of Memory A to fire and create Memory C in a brain region.

# %%
# Try varying sizes of memory A
import numpy as np
import matplotlib.pyplot as plt


# Plots memA against fired memC over a range of sizes for memA
def plot_memA_firing_against_memC_creation_single_trials(memory_A_sizes, memory_C_sizes, node_to_idx_dict, adj_matrix, k_s, memory_A_size_MIN, memory_A_size_MAX, brain_region, increment=10, num_trials=20):
  for size in range(memory_A_size_MIN, memory_A_size_MAX, increment):
    memory_A_sizes.append(size)
    # Random subset of nodes for Memory A
    memory_A = generate_random_indices_for_memory(node_to_idx_dict, size)

    # Fire memory A
    activated_nodes, memory_C_size = count_firing_inputs(adj_matrix, memory_A, k_s)

    memory_C_sizes.append(memory_C_size)
    print(f"Memory A size: {size}, Memory C size: {memory_C_size}")

# Plots several rounds of trials of: memA against fired memC over a range of sizes for memA
def plot_memA_firing_against_memC_creation(memory_A_sizes, memory_C_sizes, node_to_idx_dict, adj_matrix, k_s, memory_A_size_MIN, memory_A_size_MAX, brain_region, graphType, increment=10, num_trials=20):
  num_points = ((memory_A_size_MAX - memory_A_size_MIN) // increment) + 1
  memory_C_sizes = [0] * num_points
  memory_A_sizes = list(range(memory_A_size_MIN, memory_A_size_MAX + 1, increment))
  for i in range(num_trials):
    for idx, size in enumerate(memory_A_sizes):
      # Random subset of nodes for Memory A
      memory_A = generate_random_indices_for_memory(node_to_idx_dict, size)

      # Fire memory A
      activated_nodes, memory_C_size = count_firing_inputs(adj_matrix, memory_A, k_s)

      memory_C_sizes[idx] += memory_C_size
      print(f"Memory A size: {size}, Memory C size: {memory_C_size}, size:{size}, index:{size//increment}, num_points: {num_points}")

  # Average out mem_C size values over trials
  memory_C_sizes = [x / num_trials for x in memory_C_sizes]

  # Plot the relationship
  plt.figure(figsize=(6,4))
  plt.plot(memory_A_sizes, memory_C_sizes, marker='o', color='black', linestyle='-', markerfacecolor='gray')
  plt.xlabel("Memory A Size")
  plt.ylabel("Memory C Size", rotation=0, labelpad=40)
  plt.title(f"Memory A Size vs Memory C Size of Brain Region {brain_region}")
  plt.grid(False)
  plt.savefig(f"stability{graphType}.pdf", format='pdf', bbox_inches='tight')
  plt.show()


# Plots several rounds of trials of: memA against fired memC over a range of sizes for memA, with standard deviation error bars
def plot_memA_firing_against_memC_creation_with_error_bars(memory_A_sizes, memory_C_sizes, node_to_idx_dict, adj_matrix, k_s, memory_A_size_MIN, memory_A_size_MAX, brain_region, increment=10, num_trials=20):
  # Setup: discrete bins of memory A
  memory_A_sizes = list(range(memory_A_size_MIN, memory_A_size_MAX + 1, increment))
  num_points = len(memory_A_sizes)

  # Collect trial results (list of lists)
  all_trials = [[] for _ in range(num_points)]

  # Run trials num_trials times
  for i in range(num_trials):
    for idx, size in enumerate(memory_A_sizes):
      # Random subset of nodes for Memory A
      memory_A = generate_random_indices_for_memory(node_to_idx_dict, size)
      # Fire memory A
      activated_nodes, memory_C_size = count_firing_inputs(adj_matrix, memory_A, k_s)
      # add memory_C size to the respective list
      all_trials[idx].append(memory_C_size)

  # Compute mean and standard deviation across trials
  memory_C_sizes = [np.mean(vals) for vals in all_trials]
  memory_C_stds  = [np.std(vals) for vals in all_trials]  # or use np.std(vals)/np.sqrt(num_trials) for standard error

  # # Plot with error bars
  # plt.figure(figsize=(6,4))
  # plt.errorbar(
  #     memory_A_sizes,
  #     memory_C_sizes,
  #     yerr=memory_C_stds,
  #     fmt='-o',
  #     color='black',
  #     ecolor='gray',   # error bar color
  #     elinewidth=1,    # error bar line width
  #     capsize=4,       # add caps on error bars
  #     markerfacecolor='gray'
  # )
  # plt.xlabel("Memory A Size")
  # plt.ylabel("Memory C Size", rotation=0, labelpad=40)
  # plt.title(f"Memory A Size vs Memory C Size of Brain Region {brain_region}")
  # plt.grid(False)
  # plt.show()

  # Plot the mean line for error regions
  plt.plot(
      memory_A_sizes,
      memory_C_sizes,
      '-o',
      color='black',
      markerfacecolor='gray',
      label='Mean ± Std'
  )

  # Add the shaded error region
  plt.fill_between(
      memory_A_sizes,
      np.array(memory_C_sizes) - np.array(memory_C_stds),
      np.array(memory_C_sizes) + np.array(memory_C_stds),
      color='coral',
      alpha=0.3  # transparency level
  )

  plt.xlabel("Memory A Size")
  plt.ylabel("Memory C Size", rotation=0, labelpad=40)
  plt.title(f"Memory A Size vs Memory C Size of Brain Region {brain_region}")
  plt.grid(False)
  plt.legend()
  plt.savefig("stabilityOCG.pdf", format='pdf', bbox_inches='tight')
  plt.show()

# %% [markdown]
# ### LH_L: Plot varying sizes of Memory A to fire and create Memory C in a brain region.

# %%
# Compute the synapse strength to find the k_s, firing threshold
k_s_LH_L = compute_k_s_threshold(df_LH_L)
print(k_s_LH_L)

# Generate memory A and fire to get memory C, then plot.
brain_region_name = "LH_L"
memory_A_size_MIN = 1
memory_A_size_MAX = 1000  # different A sizes to test
k_s = k_s_LH_L
memory_A_sizes = []  # for plotting
memory_C_sizes = []  # for plotting
node_to_idx_dict = node_to_idx
adj_matrix = adj_sparse
increment = 20
num_trials = 1

# Plot varying sizes of fired nodes in Memory A against firing nodes of created Memory C
plot_memA_firing_against_memC_creation(memory_A_sizes, memory_C_sizes, node_to_idx_dict, adj_matrix, k_s,
                                       memory_A_size_MIN, memory_A_size_MAX, brain_region_name, "LHL", increment, num_trials)
# Out:
# 1.0
# Memory A size: 1, Memory C size: 13, size:1, index:0, num_points: 50
# Memory A size: 21, Memory C size: 1088, size:21, index:1, num_points: 50
# Memory A size: 41, Memory C size: 1283, size:41, index:2, num_points: 50
# Memory A size: 61, Memory C size: 1643, size:61, index:3, num_points: 50
# Memory A size: 81, Memory C size: 1977, size:81, index:4, num_points: 50
# Memory A size: 101, Memory C size: 2087, size:101, index:5, num_points: 50
# Memory A size: 121, Memory C size: 2382, size:121, index:6, num_points: 50
# Memory A size: 141, Memory C size: 2696, size:141, index:7, num_points: 50
# Memory A size: 161, Memory C size: 2459, size:161, index:8, num_points: 50
# Memory A size: 181, Memory C size: 2860, size:181, index:9, num_points: 50
# Memory A size: 201, Memory C size: 2693, size:201, index:10, num_points: 50
# Memory A size: 221, Memory C size: 2956, size:221, index:11, num_points: 50
# Memory A size: 241, Memory C size: 2900, size:241, index:12, num_points: 50
# Memory A size: 261, Memory C size: 3158, size:261, index:13, num_points: 50
# Memory A size: 281, Memory C size: 3138, size:281, index:14, num_points: 50
# Memory A size: 301, Memory C size: 3066, size:301, index:15, num_points: 50
# Memory A size: 321, Memory C size: 3231, size:321, index:16, num_points: 50
# Memory A size: 341, Memory C size: 3495, size:341, index:17, num_points: 50
# Memory A size: 361, Memory C size: 3326, size:361, index:18, num_points: 50
# Memory A size: 381, Memory C size: 3341, size:381, index:19, num_points: 50
# Memory A size: 401, Memory C size: 3499, size:401, index:20, num_points: 50
# Memory A size: 421, Memory C size: 3539, size:421, index:21, num_points: 50
# Memory A size: 441, Memory C size: 3676, size:441, index:22, num_points: 50
# Memory A size: 461, Memory C size: 3572, size:461, index:23, num_points: 50
# Memory A size: 481, Memory C size: 3582, size:481, index:24, num_points: 50
# Memory A size: 501, Memory C size: 3675, size:501, index:25, num_points: 50
# Memory A size: 521, Memory C size: 3691, size:521, index:26, num_points: 50
# Memory A size: 541, Memory C size: 3724, size:541, index:27, num_points: 50
# Memory A size: 561, Memory C size: 3630, size:561, index:28, num_points: 50
# Memory A size: 581, Memory C size: 3714, size:581, index:29, num_points: 50
# Memory A size: 601, Memory C size: 3393, size:601, index:30, num_points: 50
# Memory A size: 621, Memory C size: 3430, size:621, index:31, num_points: 50
# Memory A size: 641, Memory C size: 3501, size:641, index:32, num_points: 50
# Memory A size: 661, Memory C size: 3410, size:661, index:33, num_points: 50
# Memory A size: 681, Memory C size: 3437, size:681, index:34, num_points: 50
# Memory A size: 701, Memory C size: 3438, size:701, index:35, num_points: 50
# Memory A size: 721, Memory C size: 3474, size:721, index:36, num_points: 50
# Memory A size: 741, Memory C size: 3486, size:741, index:37, num_points: 50
# Memory A size: 761, Memory C size: 3413, size:761, index:38, num_points: 50
# Memory A size: 781, Memory C size: 3514, size:781, index:39, num_points: 50
# Memory A size: 801, Memory C size: 3466, size:801, index:40, num_points: 50
# Memory A size: 821, Memory C size: 3467, size:821, index:41, num_points: 50
# Memory A size: 841, Memory C size: 3497, size:841, index:42, num_points: 50
# Memory A size: 861, Memory C size: 3511, size:861, index:43, num_points: 50
# Memory A size: 881, Memory C size: 3501, size:881, index:44, num_points: 50
# Memory A size: 901, Memory C size: 3456, size:901, index:45, num_points: 50
# Memory A size: 921, Memory C size: 3465, size:921, index:46, num_points: 50
# Memory A size: 941, Memory C size: 3474, size:941, index:47, num_points: 50
# Memory A size: 961, Memory C size: 3434, size:961, index:48, num_points: 50
# Memory A size: 981, Memory C size: 3440, size:981, index:49, num_points: 50

# %% [markdown]
# ### OCG: Plot varying sizes of Memory A to fire and create Memory C in a brain region.

# %%
# Compute the synapse strength to find the k_s, firing threshold
k_OCG = compute_k_s_threshold(df_OCG)
print(k_OCG)

# Generate memory A and fire to get memory C, then plot.
brain_region_name_OCG = "OCG"
memory_A_size_MIN_OCG = 100
memory_A_size_MAX_OCG = 125  # different A sizes to test
k_s_OCG = k_OCG
memory_A_sizes_OCG = []  # for plotting
memory_C_sizes_OCG = []  # for plotting
node_to_idx_dict_OCG = node_to_idx_OCG
adj_matrix_OCG = adj_sparse_OCG
increment_OCG = 1
num_trials_OCG = 30

# Plot varying sizes of fired nodes in Memory A against firing nodes of created Memory C
plot_memA_firing_against_memC_creation(memory_A_sizes_OCG, memory_C_sizes_OCG, node_to_idx_dict_OCG, adj_matrix_OCG, k_s_OCG, memory_A_size_MIN_OCG,
                                       memory_A_size_MAX_OCG, brain_region_name_OCG, "OCG", increment_OCG, num_trials_OCG)
# Out:
# 2.0
# Memory A size: 100, Memory C size: 122, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 120, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 133, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 116, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 128, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 112, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 116, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 123, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 127, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 125, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 108, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 113, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 128, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 118, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 147, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 110, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 109, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 97, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 122, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 149, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 127, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 95, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 115, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 139, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 86, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 162, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 126, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 142, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 126, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 111, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 114, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 118, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 113, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 125, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 120, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 120, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 108, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 115, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 128, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 109, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 129, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 107, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 120, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 134, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 101, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 131, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 137, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 129, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 101, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 140, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 142, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 104, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 106, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 122, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 117, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 143, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 114, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 149, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 141, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 100, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 133, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 107, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 99, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 138, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 112, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 119, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 116, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 123, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 162, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 113, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 141, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 120, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 100, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 151, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 132, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 148, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 115, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 137, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 104, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 127, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 101, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 133, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 156, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 126, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 131, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 111, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 143, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 142, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 84, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 108, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 116, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 134, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 136, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 120, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 142, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 135, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 129, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 133, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 126, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 116, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 102, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 132, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 142, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 110, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 107, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 124, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 82, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 139, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 122, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 102, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 100, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 122, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 139, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 132, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 86, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 128, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 116, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 129, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 101, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 121, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 90, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 104, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 138, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 106, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 127, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 94, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 132, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 144, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 122, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 134, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 125, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 114, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 97, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 104, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 120, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 124, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 134, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 93, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 133, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 127, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 120, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 114, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 127, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 114, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 159, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 140, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 109, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 134, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 138, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 130, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 105, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 128, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 128, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 129, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 125, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 110, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 89, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 100, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 132, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 120, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 105, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 119, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 120, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 112, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 97, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 116, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 93, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 116, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 104, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 112, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 112, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 138, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 110, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 150, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 119, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 134, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 172, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 156, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 127, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 93, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 127, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 133, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 153, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 114, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 132, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 88, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 131, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 102, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 107, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 90, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 127, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 94, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 142, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 105, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 141, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 97, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 104, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 123, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 104, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 96, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 100, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 102, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 125, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 141, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 116, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 119, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 145, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 128, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 115, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 139, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 108, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 111, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 142, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 123, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 123, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 132, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 104, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 138, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 117, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 101, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 136, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 131, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 130, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 134, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 124, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 138, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 115, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 128, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 108, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 147, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 101, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 123, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 133, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 138, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 104, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 99, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 93, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 95, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 124, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 108, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 142, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 142, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 104, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 113, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 102, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 142, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 126, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 132, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 129, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 123, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 114, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 143, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 115, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 150, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 112, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 146, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 130, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 120, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 113, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 154, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 120, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 126, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 100, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 119, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 95, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 118, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 105, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 98, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 124, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 137, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 135, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 85, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 133, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 100, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 124, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 85, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 111, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 120, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 98, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 134, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 125, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 118, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 87, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 132, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 170, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 132, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 99, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 138, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 125, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 106, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 113, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 110, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 91, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 108, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 138, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 108, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 119, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 120, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 137, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 143, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 137, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 92, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 124, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 142, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 115, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 115, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 119, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 123, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 94, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 127, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 113, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 120, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 87, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 95, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 132, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 114, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 114, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 116, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 111, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 106, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 119, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 121, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 123, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 112, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 136, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 132, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 138, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 135, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 112, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 150, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 130, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 99, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 118, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 133, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 122, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 121, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 123, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 120, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 123, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 112, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 126, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 110, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 128, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 132, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 125, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 128, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 146, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 108, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 117, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 105, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 149, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 125, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 135, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 99, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 100, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 137, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 122, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 107, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 129, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 131, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 132, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 132, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 128, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 114, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 118, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 69, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 136, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 99, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 127, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 112, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 99, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 151, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 87, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 107, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 125, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 92, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 128, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 123, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 110, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 130, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 139, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 128, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 161, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 137, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 118, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 136, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 152, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 109, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 120, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 148, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 133, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 109, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 113, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 109, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 116, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 113, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 93, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 134, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 142, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 104, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 122, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 133, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 121, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 121, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 108, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 99, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 109, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 131, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 136, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 115, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 115, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 149, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 97, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 103, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 118, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 110, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 101, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 121, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 102, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 103, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 116, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 114, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 114, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 115, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 97, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 119, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 125, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 117, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 132, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 116, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 129, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 104, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 120, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 151, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 95, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 100, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 148, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 122, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 101, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 117, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 129, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 142, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 140, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 103, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 97, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 107, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 92, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 136, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 116, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 151, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 135, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 84, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 100, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 129, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 135, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 110, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 129, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 101, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 135, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 108, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 116, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 137, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 95, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 150, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 134, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 153, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 126, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 129, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 127, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 121, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 121, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 106, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 104, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 106, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 148, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 146, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 146, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 155, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 107, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 104, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 114, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 111, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 80, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 113, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 116, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 136, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 114, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 103, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 112, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 120, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 125, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 127, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 105, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 122, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 151, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 132, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 116, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 111, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 77, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 126, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 101, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 109, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 88, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 165, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 146, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 120, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 123, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 129, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 117, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 106, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 131, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 133, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 104, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 123, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 104, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 107, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 129, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 134, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 96, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 143, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 124, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 102, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 130, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 110, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 131, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 117, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 113, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 91, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 136, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 182, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 93, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 108, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 131, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 117, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 132, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 106, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 141, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 125, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 131, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 112, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 127, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 110, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 144, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 129, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 134, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 122, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 97, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 113, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 112, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 133, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 116, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 126, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 88, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 97, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 129, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 115, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 119, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 119, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 125, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 118, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 142, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 121, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 122, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 135, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 133, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 113, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 154, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 94, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 123, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 132, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 97, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 139, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 117, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 120, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 125, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 110, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 137, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 124, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 98, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 104, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 150, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 78, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 120, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 122, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 129, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 138, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 113, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 132, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 150, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 137, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 108, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 144, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 126, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 154, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 131, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 124, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 110, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 141, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 141, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 113, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 102, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 101, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 125, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 96, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 126, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 97, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 114, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 102, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 101, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 99, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 126, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 133, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 104, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 121, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 130, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 114, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 128, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 129, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 88, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 118, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 114, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 143, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 145, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 127, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 101, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 145, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 94, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 116, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 133, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 127, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 121, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 132, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 104, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 142, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 95, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 150, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 113, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 146, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 134, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 125, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 129, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 128, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 133, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 105, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 130, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 135, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 134, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 118, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 141, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 119, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 99, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 97, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 128, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 97, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 108, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 117, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 114, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 98, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 131, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 87, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 107, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 99, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 150, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 125, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 118, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 117, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 138, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 123, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 119, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 99, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 112, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 99, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 113, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 147, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 147, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 119, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 123, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 130, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 104, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 130, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 113, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 131, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 124, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 148, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 141, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 116, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 114, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 118, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 125, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 138, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 111, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 136, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 120, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 165, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 119, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 129, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 113, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 127, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 153, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 118, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 118, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 116, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 98, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 108, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 97, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 105, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 92, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 109, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 94, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 131, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 131, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 88, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 107, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 133, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 139, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 111, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 117, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 141, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 125, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 149, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 117, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 133, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 124, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 162, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 128, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 92, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 125, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 131, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 125, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 102, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 100, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 128, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 116, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 101, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 117, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 113, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 138, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 95, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 96, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 105, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 133, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 96, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 109, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 107, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 123, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 97, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 111, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 130, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 132, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 85, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 133, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 130, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 101, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 154, size:125, index:125, num_points: 26
# Memory A size: 100, Memory C size: 128, size:100, index:100, num_points: 26
# Memory A size: 101, Memory C size: 92, size:101, index:101, num_points: 26
# Memory A size: 102, Memory C size: 115, size:102, index:102, num_points: 26
# Memory A size: 103, Memory C size: 145, size:103, index:103, num_points: 26
# Memory A size: 104, Memory C size: 105, size:104, index:104, num_points: 26
# Memory A size: 105, Memory C size: 148, size:105, index:105, num_points: 26
# Memory A size: 106, Memory C size: 112, size:106, index:106, num_points: 26
# Memory A size: 107, Memory C size: 128, size:107, index:107, num_points: 26
# Memory A size: 108, Memory C size: 127, size:108, index:108, num_points: 26
# Memory A size: 109, Memory C size: 102, size:109, index:109, num_points: 26
# Memory A size: 110, Memory C size: 149, size:110, index:110, num_points: 26
# Memory A size: 111, Memory C size: 132, size:111, index:111, num_points: 26
# Memory A size: 112, Memory C size: 102, size:112, index:112, num_points: 26
# Memory A size: 113, Memory C size: 118, size:113, index:113, num_points: 26
# Memory A size: 114, Memory C size: 109, size:114, index:114, num_points: 26
# Memory A size: 115, Memory C size: 120, size:115, index:115, num_points: 26
# Memory A size: 116, Memory C size: 124, size:116, index:116, num_points: 26
# Memory A size: 117, Memory C size: 129, size:117, index:117, num_points: 26
# Memory A size: 118, Memory C size: 114, size:118, index:118, num_points: 26
# Memory A size: 119, Memory C size: 111, size:119, index:119, num_points: 26
# Memory A size: 120, Memory C size: 150, size:120, index:120, num_points: 26
# Memory A size: 121, Memory C size: 132, size:121, index:121, num_points: 26
# Memory A size: 122, Memory C size: 110, size:122, index:122, num_points: 26
# Memory A size: 123, Memory C size: 117, size:123, index:123, num_points: 26
# Memory A size: 124, Memory C size: 148, size:124, index:124, num_points: 26
# Memory A size: 125, Memory C size: 128, size:125, index:125, num_points: 26

# %%
plot_memA_firing_against_memC_creation_with_error_bars(memory_A_sizes_OCG, memory_C_sizes_OCG, node_to_idx_dict_OCG, adj_matrix_OCG, k_s_OCG, memory_A_size_MIN_OCG,
                                       memory_A_size_MAX_OCG, brain_region_name_OCG, increment_OCG, num_trials_OCG)

# %% [markdown]
# ## Stability

# %% [markdown]
# ### Fire Memory A and Memory B together to create C in a single brain region (Shared Representation).
#
#
# For the shared representation, **the size of union(A,B) should be of size 2r - (r^2 / n)**, where the resulting memory C should be about **r**.
#
# *   **(r^2 / n)** = intersection of A and B
# *   **r** = num of nodes of mem A, B, C
# *   **n** = total num of nodes in graph
# *   As A and B need to be fired at the same time, we can simply take a single, combined set of size 2r - (r^2 / n) and fire that in a 1-step JOIN to get memory C.
#
# 1.   Memory A: random subset of nodes in a brain region, overlap with B is ok.
# 2.   Memory B: random subset of nodes in a brain region, overlap with A is ok.
# 3.   Memroy C: resulting subset of nodes in a brain region that meet the firing threshold, k.
#
# If the Interference Tolerance is breached, take only unique nodes for memory C.

# %%
# Plots several rounds of trials of: memA against fired memC over a range of sizes for memA, with error regions
def plot_memAB_firing_against_memC_creation_with_error_bars(memory_AB_sizes, memory_C_sizes, node_to_idx_dict, adj_matrix, k_s, memory_AB_size_MIN, memory_AB_size_MAX, brain_region, increment=10, num_trials=20):
  # Setup: discrete bins of memory A
  memory_AB_sizes = list(range(memory_AB_size_MIN, memory_AB_size_MAX + 1, increment))
  num_points = len(memory_AB_sizes)

  # Collect trial results (list of lists)
  all_trials = [[] for _ in range(num_points)]

  # Run trials num_trials times
  for i in range(num_trials):
    for idx, size in enumerate(memory_AB_sizes):
      # Random subset of nodes for Memory AB
      memory_AB = generate_random_indices_for_memory(node_to_idx_dict, size)
      # Fire memory AB
      activated_nodes, memory_C_size = count_firing_inputs(adj_matrix, memory_AB, k_s)
      # add memory_C size to the respective list
      all_trials[idx].append(memory_C_size)

  # Compute Mean and Standard Deveiation across all trials
  memory_C_sizes = [np.mean(vals) for vals in all_trials]
  memory_C_stds  = [np.std(vals) for vals in all_trials]  # or use np.std(vals)/np.sqrt(num_trials) for standard error

  # Plot the mean line
  plt.plot(
      memory_AB_sizes,
      memory_C_sizes,
      '-o',
      color='black',
      markerfacecolor='gray',
      label='Mean ± Std'
  )

  # Add the shaded error region
  plt.fill_between(
      memory_AB_sizes,
      np.array(memory_C_sizes) - np.array(memory_C_stds),
      np.array(memory_C_sizes) + np.array(memory_C_stds),
      color='tomato',
      alpha=0.3  # transparency level
  )

  plt.xlabel("Union of Memory A and B Size")
  plt.ylabel("Memory C Size", rotation=0, labelpad=40)
  plt.title(f"Union of Memory A and Memory B Size vs. Memory C Size of Brain Region {brain_region}")
  plt.grid(False)
  plt.legend()
  plt.show()

# %%
# Plots several rounds of trials of: memA against fired memC over a range of sizes for memA, with standard deviation error bars
def plot_memAB_firing_against_memC_creation_with_error_bars_and_UNION_sizes(r_min, r_max, n, memory_AB_sizes, memory_C_sizes, node_to_idx_dict, adj_matrix, k_s, memory_AB_size_MIN, memory_AB_size_MAX, brain_region, graphType, increment=10, num_trials=20):
  # Setup: discrete bins of memory A
  memory_AB_sizes = list(range(memory_AB_size_MIN, memory_AB_size_MAX + 1, increment))
  num_points = len(memory_AB_sizes)

  # Collect trial results (list of lists)
  all_trials = [[] for _ in range(num_points)]

  # Run trials num_trials times
  for i in range(num_trials):
    for idx, size in enumerate(memory_AB_sizes):
      # Random subset of nodes for Memory AB
      memory_AB = generate_random_indices_for_memory(node_to_idx_dict, size)
      # Fire memory AB
      activated_nodes, memory_C_size = count_firing_inputs(adj_matrix, memory_AB, k_s)
      # add memory_C size to the respective list
      all_trials[idx].append(memory_C_size)

  # Compute Mean and Standard Deveiation across all trials
  memory_C_sizes = [np.mean(vals) for vals in all_trials]
  memory_C_stds  = [np.std(vals) for vals in all_trials]  # or use np.std(vals)/np.sqrt(num_trials) for standard error

  # Plot the mean line
  plt.plot(
      memory_AB_sizes,
      memory_C_sizes,
      '-o',
      color='black',
      markerfacecolor='gray',
      label='Mean ± Std'
  )

  # Add the shaded error region
  plt.fill_between(
      memory_AB_sizes,
      np.array(memory_C_sizes) - np.array(memory_C_stds),
      np.array(memory_C_sizes) + np.array(memory_C_stds),
      color='tomato',
      alpha=0.3  # transparency level
  )

  # ---- Add UNION sizes y = 2r - (r^2 / n) for same r range ----
  r_sizes = list(range(r_min, r_max + 1, increment))
  UNION_sizes = [2 * r_size - (r_size**2) // n for r_size in r_sizes]

  plt.plot(  # flip r_sizes and Union sizes so that they overlay on graph as (Union sizes, r_size created)
      UNION_sizes,
      r_sizes,
      '--',
      label=r"UNION sizes vs. r sizes $y = 2r - \frac{r^{2}}{n}$"
  )

  plt.xlabel("Union of Memory A and B Size")
  plt.ylabel("Memory C Size", rotation=0, labelpad=40)
  plt.title(f"Union of Memory A and Memory B Size vs. Memory C Size of Brain Region {brain_region}")
  plt.grid(False)
  plt.legend(loc='upper right')
  plt.savefig(f"stabilityUNIONOCG{graphType}.pdf", format='pdf', bbox_inches='tight')
  plt.show()

# %%
# Jointly fire Mem A and Mem B together to create Mem C. Use a one-step method by approximating the size union(A,B).
def JOIN_Stability_Testing(df_subgraph, r_min, r_max, n, brain_region_name, node_to_idx_dict, adj_matrix, graphType):
  # Compute the size of Union(A,B) for r_min and r_max, respectively. 2 different sizes are calculated for a range of firing values.
  union_AB_min_size = 2 * r_min - ((r_min ** 2) // n)
  union_AB_max_size = 2 * r_max - ((r_max ** 2) // n)

  # Compute the synapse strength to find the k_s, firing threshold
  k_s_subgraph = compute_k_s_threshold(df_subgraph)
  print(k_s_subgraph)

  # Generate memory A and fire to get memory C, then plot.
  k_s = k_s_subgraph

  memory_AB_size_MIN = union_AB_min_size  # different Union(A,B) sizes to test
  memory_AB_size_MAX = union_AB_max_size  # different Union(A,B) sizes to test
  memory_AB_sizes = []  # for plotting
  memory_C_sizes = []  # for plotting

  increment = 1
  num_trials = 30

  # Plot varying sizes of fired nodes in Memory A against firing nodes of created Memory C
  plot_memAB_firing_against_memC_creation_with_error_bars_and_UNION_sizes(r_min, r_max, n, memory_AB_sizes, memory_C_sizes, node_to_idx_dict, adj_matrix, k_s, memory_AB_size_MIN,
                                        memory_AB_size_MAX, brain_region_name, graphType, increment, num_trials)


# params specifically needed for 2-memory firing.
r_min_per_mem_OCG = 100
r_max_per_mem_OCG = 140
n_OCG = 409
# other params needed
df_OCG = df[df["neuropil"]=='OCG']
brain_region_name_OCG = "OCG"
node_to_idx_dict_OCG = node_to_idx_OCG
adj_matrix_OCG = adj_sparse_OCG

# Fire memory A and memory B together, with varying sizes of 100-125 nodes each.
JOIN_Stability_Testing(df_OCG, r_min_per_mem_OCG, r_max_per_mem_OCG, n_OCG, brain_region_name_OCG, node_to_idx_dict_OCG, adj_matrix_OCG, "fullUnionRange")
# Out:
# 2.0

# %% [markdown]
# It looks like the best UNION range is between [200, 220] where the anticipated sizes fall in between a standard deviation of the error region.

# %%
# params specifically needed for 2-memory firing.
r_min_per_mem_OCG = 115
r_max_per_mem_OCG = 132
n_OCG = 409
# other params needed
df_OCG = df[df["neuropil"]=='OCG']
brain_region_name_OCG = "OCG"
node_to_idx_dict_OCG = node_to_idx_OCG
adj_matrix_OCG = adj_sparse_OCG

# Fire memory A and memory B together, with varying sizes of 100-125 nodes each.
JOIN_Stability_Testing(df_OCG, r_min_per_mem_OCG, r_max_per_mem_OCG, n_OCG, brain_region_name_OCG, node_to_idx_dict_OCG, adj_matrix_OCG, "partialUnionRange")
# Out:
# 2.0

# %% [markdown]
# ## Capacity
#
# Capacity Testing

# %% [markdown]
# Run Join again and again creating Memory C1, C2, C3, ... [D]
# Every time we run and create Memory C, run a check to see how much interference there is between resulting Memory D's.
#
# Interference is what we are trying to find out! (What % of nodes are interfering with others, how many memories can we create using new A and B each generation?)
#
# *A node can belong to many memories.*
#
# **Local Interference Rate:** Check every individual node in C and in all other memories D and if more than 50% of the nodes in D are shared with C, then those 2 memories are considered to be interfering.
# * (# of interfering memories) / (# of all memories) > 10% of preexisting memories
# * Interference --> can not form the new memory, designate the graph to be 'at capacity'.
#
# **Global Interference:** If **more than 10% of all nodes in the whole graph** (OCG) belong to 2+ memories --> Interference Found!

# %%
# Jointly fire Mem A and Mem B together to create Mem C. Use a one-step method by approximating the size union(A,B).
def JOIN_Capacity_Simulation(df_subgraph, r_min, r_max, n, brain_region_name, node_to_idx_dict, adj_matrix):
  # Compute the size of Union(A,B) for r_min and r_max, respectively. 2 different sizes are calculated for a range of firing values.
  union_AB_min_size = 2 * r_min - ((r_min ** 2) // n) - 1
  union_AB_max_size = 2 * r_max - ((r_max ** 2) // n) - 1

  # Compute the synapse strength to find the k_s, firing threshold
  k_s_subgraph = compute_k_s_threshold(df_subgraph)
  print(k_s_subgraph)

  # Generate memory A and fire to get memory C, then plot.
  k_s = k_s_subgraph

  memory_AB_size_MIN = union_AB_min_size  # different Union(A,B) sizes to test
  memory_AB_size_MAX = union_AB_max_size  # different Union(A,B) sizes to test
  memory_AB_sizes = []  # for plotting
  stable_memories_sizes = []  # for plotting

  increment = 1

  # Plot varying sizes of fired nodes in Memory A against firing nodes of created Memory C
  memory_AB_sizes, stable_memories_sizes, stable_memories_stds = plot_memAB_firing_against_memC_Capacity_Testing_with_error_bars(memory_AB_sizes, stable_memories_sizes, node_to_idx_dict, adj_matrix, k_s, memory_AB_size_MIN,
                                        memory_AB_size_MAX, brain_region_name, "OCG", increment)
  return memory_AB_sizes, stable_memories_sizes, stable_memories_stds


# Plots several rounds of trials of: memA against fired memC over a range of sizes for memA, with standard deviation error bars
def plot_memAB_firing_against_memC_Capacity_Testing_with_error_bars(memory_AB_sizes, stable_memories_sizes, node_to_idx_dict, adj_matrix, k_s, memory_AB_size_MIN, memory_AB_size_MAX, brain_region, graphType, increment=1, num_trials=30):
  # Setup Local and Global Interference expectations
  LOCAL_INTERFERENCE_THRESHOLD = 0.5
  GLOBAL_INTERFERENCE_THRESHOLD = 0.1

  # Setup: discrete bins of memory AB
  memory_AB_sizes = list(range(memory_AB_size_MIN, memory_AB_size_MAX + 1, increment))

  # Store num stable memories per Union(A,B) size, across num_trials
  stable_memories_per_AB_size = [[] for _ in range(len(memory_AB_sizes))]
  Global_interference_per_AB_size = [[] for _ in range(len(memory_AB_sizes))]

  for i in range(num_trials):
    # Collect Memory results (list of lists) and Global Interference results
    num_points = len(memory_AB_sizes)
    all_trials = [[] for _ in range(num_points)]
    Global_Interference_Levels_per_AB_Size = [0.0] * num_points

    # Perform Capacity Testing 1x for each size in range of AB_Union_min, AB_Union_max
    for idx, size in enumerate(memory_AB_sizes):
      num_interfering_memories = 0
      Global_Interference_Level = 0.0
      interference_capacity_reached = False
      # Generate Memories and Evaluate Interference
      while not interference_capacity_reached:
        # Generate Memories
        # Random subset of nodes for Memory AB
        memory_AB = generate_random_indices_for_memory(node_to_idx_dict, size)
        # Fire memory AB
        activated_nodes, memory_C_size = count_firing_inputs(adj_matrix, memory_AB, k_s)

        # Evaluate Interference between memory C and all other memories D
        num_all_memories_D = len(all_trials[idx])
        for mem in all_trials[idx]:
          recurrence_nodes = np.intersect1d(activated_nodes, mem)
          # Local interference found
          if len(recurrence_nodes) / len(activated_nodes) >= LOCAL_INTERFERENCE_THRESHOLD:
            num_interfering_memories += 2

        # Check for global interference threshold (+1 is to count the last memory C generated in addition to the Memories D)
        Global_Interference_Level = num_interfering_memories / (num_all_memories_D + 1)
        if Global_Interference_Level >= GLOBAL_INTERFERENCE_THRESHOLD:
          interference_capacity_reached = True
          Global_Interference_Levels_per_AB_Size[idx] = Global_Interference_Level
        else:
          all_trials[idx].append(activated_nodes)

      # Store this trial. Keep track of the number of memories for this Union(A,B) size AND the Global interference
      stable_memories_per_AB_size[idx].append(len(all_trials[idx]))
      Global_interference_per_AB_size[idx].append(Global_Interference_Levels_per_AB_Size[idx])


  # Compute Mean and Standard Deviation of num stable memories, across all trials
  stable_memories_sizes = [np.mean(vals) for vals in stable_memories_per_AB_size]
  stable_memories_stds  = [np.std(vals) for vals in stable_memories_per_AB_size]  # or use np.std(vals)/np.sqrt(num_trials) for standard error

  # Print Results from trials
  zipped_trial_data = list(zip(memory_AB_sizes, Global_interference_per_AB_size, stable_memories_sizes))
  print("AB_size, GLOBAL INTERFERENCE LEVEL, Number of Memories D:")
  for ab_size, global_level, memories in zipped_trial_data:
    print(ab_size, np.mean(global_level), memories)


  # # Plot with error bars
  # plt.figure(figsize=(6,4))
  # plt.errorbar(
  #     memory_AB_sizes,
  #     stable_memories_sizes,
  #     yerr=stable_memories_stds,
  #     fmt='-o',
  #     color='black',
  #     ecolor='gray',   # error bar color
  #     elinewidth=1,    # error bar line width
  #     capsize=4,       # add caps on error bars
  #     markerfacecolor='gray'
  # )
  # plt.xlabel("Union of Memory A and B Size")
  # plt.ylabel("Number of Memories at Capacity", rotation=0, labelpad=85)
  # plt.title(f"Union of Memory A and Memory B Size vs. The Number of Memories at Capacity of {brain_region}")
  # plt.grid(False)
  # plt.show()

  # Plot the mean line for error region
  plt.plot(
      memory_AB_sizes,
      stable_memories_sizes,
      '-o',
      color='black',
      markerfacecolor='gray',
      label='Mean ± Std'
  )

  # Add the shaded error region
  plt.fill_between(
      memory_AB_sizes,
      np.array(stable_memories_sizes) - np.array(stable_memories_stds),
      np.array(stable_memories_sizes) + np.array(stable_memories_stds),
      color='tomato',
      alpha=0.3  # transparency of the shaded area
  )

  plt.xlabel("Union of Memory A and B Size")
  plt.ylabel("Number of Memories\n at Capacity", rotation=0, labelpad=50)
  plt.title(f"Union of Memory A and Memory B Size vs. The Number\n of Memories at Capacity of {brain_region}")
  plt.grid(False)
  plt.legend()
  plt.savefig(f"capacityChart_{graphType}.pdf", format='pdf', bbox_inches='tight')
  plt.show()
  return memory_AB_sizes, stable_memories_sizes, stable_memories_stds

# %%
# CAP Test for JOIN on OCG

# params specifically needed for 2-memory firing.
r_min_per_mem_OCG = 100
r_max_per_mem_OCG = 125
n_OCG = 409
# other params needed
df_OCG = df[df["neuropil"]=='OCG']
brain_region_name_OCG = "Brain Region OCG"
node_to_idx_dict_OCG = node_to_idx_OCG
adj_matrix_OCG = adj_sparse_OCG

# Fire memory A and memory B together, with varying sizes of 100-125 nodes each.
OCG_memory_AB_sizes, OCG_stable_memories_sizes, OCG_stable_memories_stds = JOIN_Capacity_Simulation(df_OCG, r_min_per_mem_OCG, r_max_per_mem_OCG, n_OCG, brain_region_name_OCG, node_to_idx_dict_OCG, adj_matrix_OCG)
# Out:
# 2.0
# AB_size, GLOBAL INTERFERENCE LEVEL, Number of Memories D:
# 175 0.6057142857142856 3.2333333333333334
# 176 0.6687301587301587 2.966666666666667
# 177 0.5893915343915342 3.8
# 178 0.633968253968254 3.6
# 179 0.6225925925925926 3.966666666666667
# 180 0.5778571428571428 3.966666666666667
# 181 0.5894444444444443 3.1
# 182 0.6602380952380951 3.6333333333333333
# 183 0.5124603174603175 4.3
# 184 0.5915632515632515 3.7
# 185 0.5967989417989418 3.8333333333333335
# 186 0.5471765271765272 3.8666666666666667
# 187 0.5806715506715506 3.8
# 188 0.4793410293410293 4.633333333333334
# 189 0.49714285714285716 4.466666666666667
# 190 0.5336507936507936 4.333333333333333
# 191 0.5603439153439155 4.2
# 192 0.5530423280423281 4.666666666666667
# 193 0.4793915343915343 4.733333333333333
# 194 0.5437789987789988 4.033333333333333
# 195 0.49312409812409813 4.8
# 196 0.4124338624338624 5.566666666666666
# 197 0.4539706589706591 5.033333333333333
# 198 0.4548396048396049 4.7
# 199 0.38583435083435086 6.4
# 200 0.41928645428645434 5.8
# 201 0.3412236456354103 7.4
# 202 0.36919629390217623 6.866666666666666
# 203 0.4206315906315906 6.433333333333334
# 204 0.29774810157163095 7.533333333333333
# 205 0.3155253936523286 8.233333333333333
# 206 0.3796957671957672 7.0
# 207 0.2966899426109953 8.766666666666667
# 208 0.34209925552030807 8.066666666666666
# 209 0.32989658489658485 7.566666666666666
# 210 0.29429468679468673 9.5
# 211 0.2796265974594148 9.3

# %% [markdown]
# ### Capacity Testing on Watts-Strogatz graphs.

# %%
import numpy as np
import itertools
from scipy.sparse import coo_matrix

# Jointly fire Mem A and Mem B together to create Mem C. Use a one-step method by approximating the size union(A,B).
def JOIN_WS_Capacity_Simulation(k_s_subgraph, r_min, r_max, n, brain_region_name, node_to_idx_dict, adj_matrix):
  # Compute the size of Union(A,B) for r_min and r_max, respectively. 2 different sizes are calculated for a range of firing values.
  union_AB_min_size = 2 * r_min - ((r_min ** 2) // n) - 1
  union_AB_max_size = 2 * r_max - ((r_max ** 2) // n) - 1

  # Generate memory A and fire to get memory C, then plot.
  k_s = k_s_subgraph

  memory_AB_size_MIN = union_AB_min_size  # different Union(A,B) sizes to test
  memory_AB_size_MAX = union_AB_max_size  # different Union(A,B) sizes to test
  memory_AB_sizes = []  # for plotting
  memory_C_sizes = []  # for plotting

  increment = 1
  num_trials = 30

  # Plot varying sizes of fired nodes in Memory A against firing nodes of created Memory C
  memory_AB_sizes, stable_memories_sizes, stable_memories_stds = plot_memAB_firing_against_memC_Capacity_Testing_with_error_bars(memory_AB_sizes, memory_C_sizes, node_to_idx_dict, adj_matrix, k_s, memory_AB_size_MIN,
                                        memory_AB_size_MAX, brain_region_name, "WS", increment, num_trials)
  return memory_AB_sizes, stable_memories_sizes, stable_memories_stds


# Generate a Watts–Strogatz small-world network adjacency matrix in sparse format.
# n = Number of nodes
# p = Rewiring probability
# k = Each node is connected to k nearest neighbors in a ring lattice (graph degree/ for directed graph)
# directed = Whether the graph is directed (True) or undirected (False)
# seed = Random seed for reproducibility
def create_ws_graph_sparse(n: int, p: float, knn: int = -1, directed: bool = True, seed=None):
    if knn == -1:
        knn = int((n + np.log(n)) // 2)
    if knn > n:
        raise ValueError("knn cannot be larger than n")
    if knn == n:
        return coo_matrix(np.eye(n)).tocsr()

    rng = np.random.default_rng(seed)

    # Collect edges for sparse adj matrix
    rows = []
    cols = []

    pool = rng.random(n * knn)
    for pix, (n_ix, iy) in enumerate(itertools.product(range(n), range(1, knn + 1))):
        idx = n_iy = (n_ix + iy) % n  # lattice neighbor
        if pool[pix] < p:
            # rewire each edge of k-nearest neighbors with probability p to a random node
            while idx == n_ix or idx == n_iy:
                idx = rng.integers(0, n)
        rows.append(n_ix)
        cols.append(idx)

        if not directed:
            rows.append(idx)
            cols.append(n_ix)

    data = np.ones(len(rows), dtype=int)
    adj_sparse = coo_matrix((data, (rows, cols)), shape=(n, n)).tocsr()

    # Make sure it stays binary (no multi-edges summing to >1)
    adj_sparse.data[:] = 1

    return adj_sparse

# direct = Directed Boolean
# n = Number of nodes
# d = degree of biological graph (drosophila)
# p = Edge probability
def compute_p(n, d, directed):
  if directed:
    return d / (2 * (n - 1))
  else:
    return d / (n - 1)

# %% [markdown]
# #### Try a range of n nodes to observe the change in interference and stable memories.
#
#
#
# *   n = 409
# *   d = 12
#
# Emulates the Stability of OCG over different AB Union sizes well.

# %%
import math

# Try various n node sizes over a range of [380, 420] to understand the effect on
varying_n_over_WS = [409]
for n in varying_n_over_WS:
  # Compute Adj_Matrix, Small-World Metrics for WS Graph using OCG Small-World Metrics
  ws_OCG_n = n
  ws_OCG_d = 12
  ws_OCG_k = int(k_s_OCG)
  print("k: ", ws_OCG_k)
  ws_OCG_directed = True
  ws_OCG_p = compute_p(ws_OCG_n, ws_OCG_d, ws_OCG_directed)
  print("p: ", ws_OCG_p)
  ws_OCG_knn = math.ceil(ws_OCG_d / 2)
  ws_adj_matrix_OCG = create_ws_graph_sparse(ws_OCG_n, ws_OCG_p, ws_OCG_knn)

  # Compute WS Small World Metrics
  deg_dist_WS_OCG_IN, deg_dist_WS_OCG_OUT = calculate_degree_distribution(ws_adj_matrix_OCG, ws_OCG_directed)
  print("In-Degree Distribution: ", np.mean(deg_dist_WS_OCG_IN))
  print("Out-Degree Distribution: ", np.mean(deg_dist_WS_OCG_OUT))

  # Compute Clustering Coefficient
  clustCoeff_WS_OCG = calculate_global_clustering_sparse(ws_adj_matrix_OCG, ws_OCG_directed)
  print("Clustering Coefficient: ", clustCoeff_WS_OCG)

  # Compute Characteristic Path Length
  characteristic_path_length_WS_OCG = calculate_path_length_sparse(ws_adj_matrix_OCG, ws_OCG_directed)
  print("Path Length: ", characteristic_path_length_WS_OCG)

  # Compute Average Degree of Graph
  print("Average Degree of Graph:", compute_graph_average_degree(ws_adj_matrix_OCG, ws_OCG_directed))

  # Fire Memory A and Memory B in the WS Small Worlds Graph to simulate JOIN
  r_min_per_mem_OCG = 100
  r_max_per_mem_OCG = 125

  # other params needed
  ws_brain_region_name_OCG = "WS Graph of OCG Qualities (n, d, k)"
  node_to_idx_dict_OCG = [0] * ws_OCG_n

  # Fire memory A and memory B together, with varying sizes of 100-125 nodes each.
  WS_memory_AB_sizes, WS_stable_memories_sizes, WS_stable_memories_stds = JOIN_WS_Capacity_Simulation(ws_OCG_k, r_min_per_mem_OCG, r_max_per_mem_OCG, ws_OCG_n, ws_brain_region_name_OCG, node_to_idx_dict_OCG, ws_adj_matrix_OCG)
# Out:
# k:  2
# p:  0.014705882352941176
# In-Degree Distribution:  5.997555012224939
# Out-Degree Distribution:  5.997555012224939
# Clustering Coefficient:  0.32697577957188356
# Path Length:  10.478007095258642
# Average Degree of Graph: 11.995110024449877
# AB_size, GLOBAL INTERFERENCE LEVEL, Number of Memories D:
# 175 0.6166931216931216 3.433333333333333
# 176 0.5746031746031746 3.3
# 177 0.562962962962963 3.533333333333333
# 178 0.5253968253968254 3.6333333333333333
# 179 0.6538888888888889 3.1333333333333333
# 180 0.5545238095238095 3.533333333333333
# 181 0.6423809523809524 3.1666666666666665
# 182 0.5723015873015871 3.6
# 183 0.5726479076479076 4.166666666666667
# 184 0.5794098494098493 3.4
# 185 0.6307936507936508 3.466666666666667
# 186 0.5957142857142856 3.2666666666666666
# 187 0.4580952380952381 4.133333333333334
# 188 0.5599470899470899 3.9
# 189 0.4937566137566138 4.033333333333333
# 190 0.5737349687349688 4.533333333333333
# 191 0.5697385947385947 4.4
# 192 0.5793915343915343 3.8333333333333335
# 193 0.4354497354497354 4.8
# 194 0.5021452621452621 4.366666666666666
# 195 0.4596825396825397 4.133333333333334
# 196 0.4406084656084656 4.6
# 197 0.5005555555555555 4.1
# 198 0.5062481962481963 4.666666666666667
# 199 0.4982804232804233 4.466666666666667
# 200 0.47188071188071196 5.166666666666667
# 201 0.413104858104858 5.4
# 202 0.3737284937284937 5.933333333333334
# 203 0.36193676693676696 5.866666666666666
# 204 0.3833124283124283 6.033333333333333
# 205 0.3858994708994709 5.6
# 206 0.40059644059644056 6.1
# 207 0.3423725348725349 6.633333333333334
# 208 0.39277370777370774 6.133333333333334
# 209 0.30423239709045335 7.8
# 210 0.2929974002032826 8.566666666666666
# 211 0.26177202427202423 8.033333333333333

# %% [markdown]
# ### Plot OCG and WS Capacity Distributions on Top of One Another

# %%
def JOIN_BOTH_Capacity_Simulation(df_OCG, r_min_per_mem_OCG, r_max_per_mem_OCG, n_OCG, brain_region_name_OCG, node_to_idx_dict_OCG, adj_matrix_OCG,
    ws_OCG_k, ws_OCG_n, ws_brain_region_name_OCG, ws_adj_matrix_OCG):
  OCG_memory_AB_sizes, OCG_stable_memories_sizes, OCG_stable_memories_stds = JOIN_Capacity_Simulation(df_OCG, r_min_per_mem_OCG, r_max_per_mem_OCG, n_OCG, brain_region_name_OCG, node_to_idx_dict_OCG, adj_matrix_OCG)
  WS_memory_AB_sizes, WS_stable_memories_sizes, WS_stable_memories_stds = JOIN_WS_Capacity_Simulation(ws_OCG_k, r_min_per_mem_OCG, r_max_per_mem_OCG, ws_OCG_n, ws_brain_region_name_OCG, node_to_idx_dict_OCG, ws_adj_matrix_OCG)

  ###### PLOT OCG ######
  # Plot the mean line for error region
  plt.plot(
      OCG_memory_AB_sizes,
      OCG_stable_memories_sizes,
      '-o',
      color='black',
      markerfacecolor='red',
      label='OCG Mean ± Std'
  )

  # Add the shaded error region
  plt.fill_between(
      OCG_memory_AB_sizes,
      np.array(OCG_stable_memories_sizes) - np.array(OCG_stable_memories_stds),
      np.array(OCG_stable_memories_sizes) + np.array(OCG_stable_memories_stds),
      color='tomato',
      alpha=0.3  # transparency of the shaded area
  )

  ###### PLOT WS ######
  # Plot the mean line for error region
  plt.plot(
      WS_memory_AB_sizes,
      WS_stable_memories_sizes,
      '-o',
      color='black',
      markerfacecolor='blue',
      label='WS Mean ± Std'
  )

  # Add the shaded error region
  plt.fill_between(
      WS_memory_AB_sizes,
      np.array(WS_stable_memories_sizes) - np.array(WS_stable_memories_stds),
      np.array(WS_stable_memories_sizes) + np.array(WS_stable_memories_stds),
      color='blue',
      alpha=0.3  # transparency of the shaded area
  )

  plt.xlabel("Union of Memory A and B Size")
  plt.ylabel("Number of Memories\n at Capacity", rotation=0, labelpad=60)
  plt.title(f"Union of Memory A and Memory B Size vs. The Number\n of Memories at Capacity Between OCG and WS")
  plt.grid(False)
  plt.legend()
  plt.savefig(f"capacityChart_Overlay.pdf", format='pdf', bbox_inches='tight')
  plt.show()

JOIN_BOTH_Capacity_Simulation(df_OCG, r_min_per_mem_OCG, r_max_per_mem_OCG, n_OCG, brain_region_name_OCG, node_to_idx_dict_OCG, adj_matrix_OCG,
    ws_OCG_k, ws_OCG_n, ws_brain_region_name_OCG, ws_adj_matrix_OCG)
# Out:
# 2.0
# AB_size, GLOBAL INTERFERENCE LEVEL, Number of Memories D:
# 175 0.6938095238095238 3.5
# 176 0.5913756613756613 3.3333333333333335
# 177 0.5628138528138525 3.8333333333333335
# 178 0.6830471380471381 3.3333333333333335
# 179 0.6068253968253967 3.1666666666666665
# 180 0.5581746031746032 3.8
# 181 0.658042328042328 3.3333333333333335
# 182 0.5189417989417989 4.133333333333334
# 183 0.6262433862433862 3.433333333333333
# 184 0.5724603174603173 3.7333333333333334
# 185 0.5765873015873014 3.8
# 186 0.5205555555555555 3.933333333333333
# 187 0.522010582010582 4.2
# 188 0.4538936988936989 5.5
# 189 0.554126984126984 4.133333333333334
# 190 0.5053968253968254 4.2
# 191 0.4698544973544974 4.533333333333333
# 192 0.4541412291412292 5.066666666666666
# 193 0.4819095719095719 4.9
# 194 0.39561469032057267 5.7
# 195 0.40749158249158257 5.3
# 196 0.36536463536463537 6.3
# 197 0.41585137085137086 5.9
# 198 0.4028891478891478 6.0
# 199 0.4209952084952085 5.9
# 200 0.4188359788359788 5.4
# 201 0.38171497892086126 6.0
# 202 0.32412882324647024 7.3
# 203 0.3328795278795278 6.733333333333333
# 204 0.3159115202536255 7.266666666666667
# 205 0.3949413549413549 6.9
# 206 0.2957979982979983 8.266666666666667
# 207 0.33689791002484504 7.666666666666667
# 208 0.2516020091020091 8.166666666666666
# 209 0.33425734396322626 7.4
# 210 0.3031912531912532 7.7
# 211 0.28322152792741023 8.0
# AB_size, GLOBAL INTERFERENCE LEVEL, Number of Memories D:
# 175 0.5959788359788359 3.1333333333333333
# 176 0.5507936507936507 3.3666666666666667
# 177 0.5709523809523809 3.2666666666666666
# 178 0.5295238095238096 3.8666666666666667
# 179 0.6885714285714285 3.2333333333333334
# 180 0.6679365079365079 2.8333333333333335
# 181 0.5969841269841268 3.066666666666667
# 182 0.6138888888888888 3.1333333333333333
# 183 0.48563492063492064 4.233333333333333
# 184 0.5650793650793651 3.2666666666666666
# 185 0.5117195767195768 4.433333333333334
# 186 0.5221428571428571 3.9
# 187 0.5351587301587302 3.4
# 188 0.5234920634920635 3.7
# 189 0.48730399230399235 4.666666666666667
# 190 0.5537830687830687 3.8
# 191 0.5271957671957671 4.066666666666666
# 192 0.45039682539682546 4.4
# 193 0.5562698412698414 3.933333333333333
# 194 0.4846849446849447 4.466666666666667
# 195 0.5557190957190957 3.8333333333333335
# 196 0.5273328523328523 4.333333333333333
# 197 0.4377777777777778 4.5
# 198 0.469017834017834 5.066666666666666
# 199 0.4399180449180449 5.566666666666666
# 200 0.5382082732082732 4.5
# 201 0.5121031746031747 4.366666666666666
# 202 0.45738335738335745 4.5
# 203 0.4527801827801828 4.8
# 204 0.37990139490139485 6.166666666666667
# 205 0.3485789210789211 6.433333333333334
# 206 0.35000314500314494 6.9
# 207 0.33891583362171596 7.3
# 208 0.3812035187035187 7.4
# 209 0.33821502571502565 7.833333333333333
# 210 0.3302069508591248 7.8
# 211 0.2913458763458763 8.066666666666666

# %% [markdown]
# #### Make a WS Graph with tested interference and stability ranges. Then test to verify the WS Graph meets small world metrics.
#
#
#
#
# *   Watts-Strogatz is much more uniform due to the way the nodes are connected to each other than the real world brain connections of OCG. It is possible that OCG has more threshold for misfires, as the graph is not completely connected. Thus, we would not need as many edges to achieve the same connectivity. This is why we have a smaller **d**.
# *   n is 400 vs. 409 of OCG. This is a difference of ~10 nodes. Not a large consideration.
#
#
# MemA and MemB Union size of [200, 210] ==> 30 trials
# Use error bars with mean and st dev.

# %%
# Compute Adj_Matrix, Small-World Metrics for WS Graph using OCG Small-World Metrics
import math
ws_OCG_n = 409
ws_OCG_d = 12
ws_OCG_k = int(k_s_OCG)
print("k: ", ws_OCG_k)

ws_OCG_directed = True
ws_OCG_p = compute_p(ws_OCG_n, ws_OCG_d, ws_OCG_directed)
print("p: ", ws_OCG_p)

ws_OCG_knn = math.ceil(ws_OCG_d / 2)
ws_adj_matrix_OCG = create_ws_graph_sparse(ws_OCG_n, ws_OCG_p, ws_OCG_knn)

# Compute WS Small World Metrics
deg_dist_WS_OCG_IN, deg_dist_WS_OCG_OUT = calculate_degree_distribution(ws_adj_matrix_OCG, ws_OCG_directed)
print("In-Degree Distribution: ", np.mean(deg_dist_WS_OCG_IN))
print("Out-Degree Distribution: ", np.mean(deg_dist_WS_OCG_OUT))

# Compute Clustering Coefficient
clustCoeff_WS_OCG = calculate_global_clustering_sparse(ws_adj_matrix_OCG, ws_OCG_directed)
print("Clustering Coefficient: ", clustCoeff_WS_OCG)

# Compute Characteristic Path Length
characteristic_path_length_WS_OCG = calculate_path_length_sparse(ws_adj_matrix_OCG, ws_OCG_directed)
print("Path Length: ", characteristic_path_length_WS_OCG)

# Compute Average Degree of Graph
graph_average_degree_WS_OCG = compute_graph_average_degree(ws_adj_matrix_OCG, ws_OCG_directed)
print("Average Degree of Graph:", graph_average_degree_WS_OCG)
# Out:
# k:  2
# p:  0.015037593984962405
# In-Degree Distribution:  5.9975
# Out-Degree Distribution:  5.9975
# Clustering Coefficient:  0.32581036049681916
# Path Length:  10.831773182957393
# Average Degree of Graph: 11.995

# %%
# Small World Test on WS Graph with Above n,d,k

# Find Graph Average Degree to use in random Gnp graph calculation
print(compute_graph_average_degree(ws_adj_matrix_OCG, ws_OCG_directed))
# Out:
# 11.995

# %%
# import C_rand, L_rand values from randGraph.ipynb
C_rand_WS = 0.015730598927988813
L_rand_WS = 3.589833550913838
S_WS = compute_small_world_threshold(clustCoeff_WS_OCG, characteristic_path_length_WS_OCG, C_rand, L_rand)
print(S_WS)

if S_WS > 1:
  print("Small world found!")
else:
  print("Not a small world...")
# Out:
# 9.460053505960435
# Small world found!

# %%
# Fire Memory A and Memory B in the WS Small Worlds Graph to simulate JOIN
r_min_per_mem_OCG = 117
r_max_per_mem_OCG = 124

# other params needed
ws_brain_region_name_OCG = "WS of OCG Qualities (n, d, k)"
node_to_idx_dict_OCG = [0] * ws_OCG_n

# Fire memory A and memory B together, with varying sizes of 100-125 nodes each.
JOIN_WS_Capacity_Simulation(ws_OCG_k, r_min_per_mem_OCG, r_max_per_mem_OCG, ws_OCG_n, ws_brain_region_name_OCG, node_to_idx_dict_OCG, ws_adj_matrix_OCG)
# Out:
# AB_size, GLOBAL INTERFERENCE LEVEL, Number of Memories D:
# 200 0.4583845783845784 5.4
# 201 0.3395469345469345 6.733333333333333
# 202 0.3979234926293749 6.233333333333333
# 203 0.36129703629703624 6.333333333333333
# 204 0.38321369663474925 6.6
# 205 0.3004214888425415 7.5
# 206 0.36212144866943624 7.633333333333334
# 207 0.3085966810966811 7.033333333333333
# 208 0.41274212715389186 6.566666666666666
# 209 0.28537400507988747 8.466666666666667
# 210 0.34826703891921285 8.166666666666666

# %% [markdown]
# ## Reliability - Future Work...Outside of the scope of this Thesis.
#
# Recall Tests
# Verification of
# After reaching capacity on a graph, fire (A,B) nodes again and see if the following memories C also fire as expected. We want to see if after MemC is created, if that interferes with A or B.

# %% [markdown]
# ## Visualize Brain Region Subgraphs

# %% [markdown]
# ### OCG

# %%
# OVERALL OCG GRAPH
import networkx as nx
import matplotlib.pyplot as plt

# Take adj_sparse (CSR matrix)
# Convert sparse matrix to a NetworkX Graph
G = nx.from_scipy_sparse_array(adj_matrix_OCG, create_using=nx.DiGraph)
pos = nx.spring_layout(G, seed=0)

# Draw the graph
plt.figure(figsize=(8, 8))
nx.draw(
    G,
    node_size=50,          # smaller nodes
    node_color="black",    # black nodes
    edge_color="gray",     # gray edges
    width=0.5,
    alpha=0.7,
    with_labels=False      # turn on if you want node labels
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4064958855.py in <cell line: 0>()
#      10 # Draw the graph
#      11 plt.figure(figsize=(8, 8))
# ---> 12 nx.draw(
#      13     G,
#      14     node_size=50,          # smaller nodes
#
# /usr/local/lib/python3.12/dist-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#    1162         kwds["with_labels"] = "labels" in kwds
#    1163
# -> 1164     draw_networkx(G, pos=pos, ax=ax, **kwds)
#    1165     ax.set_axis_off()
#    1166     plt.draw_if_interactive()
#
# /usr/local/lib/python3.12/dist-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#    1348
#    1349     if pos is None:
# -> 1350         pos = nx.drawing.spring_layout(G)  # default to spring layout
#    1351
#    1352     draw_networkx_nodes(G, pos, **node_kwds)
#
# /usr/local/lib/python3.12/dist-packages/networkx/utils/decorators.py in argmap_spring_layout_17(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed, store_pos_as, method, gravity)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# /usr/local/lib/python3.12/dist-packages/networkx/drawing/layout.py in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed, store_pos_as, method, gravity)
#     641             nnodes, _ = A.shape
#     642             k = dom_size / np.sqrt(nnodes)
# --> 643         pos = _fruchterman_reingold(
#     644             A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     645         )
#
# /usr/local/lib/python3.12/dist-packages/networkx/utils/decorators.py in argmap__fruchterman_reingold_25(A, k, pos, fixed, iterations, threshold, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# /usr/local/lib/python3.12/dist-packages/networkx/drawing/layout.py in _fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     697         delta = pos[:, np.newaxis, :] - pos[np.newaxis, :, :]
#     698         # distance between points
# --> 699         distance = np.linalg.norm(delta, axis=-1)
#     700         # enforce minimum distance of 0.01
#     701         np.clip(distance, 0.01, None, out=distance)
#
# /usr/local/lib/python3.12/dist-packages/numpy/linalg/_linalg.py in _norm_dispatcher(x, ord, axis, keepdims)
#    2560
#    2561
# -> 2562 def _norm_dispatcher(x, ord=None, axis=None, keepdims=None):
#    2563     return (x,)
#    2564
#
# KeyboardInterrupt:

# %%
# ZOOMED IN VIEW ON CENTRAL CLUSTER OF NODES
import networkx as nx
import matplotlib.pyplot as plt

# If you already have adj_sparse from your function (CSR matrix)
# Convert sparse matrix to a NetworkX Graph
G = nx.from_scipy_sparse_array(adj_matrix_OCG, create_using=nx.DiGraph)
pos = nx.spring_layout(G, seed=0)

# Draw the graph
plt.figure(figsize=(12, 12))
nx.draw(
    G,
    node_size=50,          # smaller nodes
    node_color="black",    # black nodes
    edge_color="gray",     # gray edges
    width=0.5,
    alpha=0.7,
    with_labels=False      # turn on if you want node labels
)

# ZOOM IN ON THE LARGE CENTRAL CLUSTER
plt.xlim(-0.1, 0.15)   # tighter zoom horizontally
plt.ylim(-0.1, 0.1)   # tighter zoom vertically

plt.show()

# %%
# ZOOMED IN VIEW ON CENTRAL CLUSTER OF NODES
import networkx as nx
import matplotlib.pyplot as plt

# If you already have adj_sparse from your function (CSR matrix)
# Convert sparse matrix to a NetworkX Graph
G = nx.from_scipy_sparse_array(adj_matrix_OCG, create_using=nx.DiGraph)
pos = nx.spring_layout(G, seed=0)

# Draw the graph
plt.figure(figsize=(12, 12))
nx.draw(
    G,
    node_size=50,          # smaller nodes
    node_color="black",    # black nodes
    edge_color="gray",     # gray edges
    width=0.5,
    alpha=0.7,
    with_labels=True,
    font_size=15,
    font_color="red"
)

# # Add labels separately with an offset (d_y shift upwards)
# labels = {n: str(n) for n in G.nodes()}
# label_pos = {n: (x, y + 0.00000001) for n, (x, y) in pos.items()}

# nx.draw_networkx_labels(
#     G,
#     label_pos,
#     labels,
#     font_size=8,
#     font_color="red"   # choose a contrasting color
# )

# ZOOM IN ON THE LARGE CENTRAL CLUSTER
plt.xlim(-0.1, 0.15)   # tighter zoom horizontally
plt.ylim(-0.1, 0.1)   # tighter zoom vertically

plt.show()

# %%
# OVERALL LH_L GRAPH
import networkx as nx
import matplotlib.pyplot as plt

# Take adj_sparse (CSR matrix)
# Convert sparse matrix to a NetworkX Graph
G = nx.from_scipy_sparse_array(adj_matrix, create_using=nx.DiGraph)
pos = nx.spring_layout(G, seed=0)

# Draw the graph
plt.figure(figsize=(8, 8))
nx.draw(
    G,
    node_size=50,          # smaller nodes
    node_color="black",    # black nodes
    edge_color="gray",     # gray edges
    width=0.5,
    alpha=0.7,
    with_labels=False      # turn on if you want node labels
)

plt.show()

# %%
# ZOOMED IN VIEW ON CENTRAL CLUSTER OF NODES

# Convert sparse matrix to a NetworkX Graph
G = nx.from_scipy_sparse_array(adj_matrix, create_using=nx.DiGraph)
pos = nx.spring_layout(G, seed=0)

# Draw the graph
plt.figure(figsize=(12, 12))
nx.draw(
    G,
    node_size=50,          # smaller nodes
    node_color="black",    # black nodes
    edge_color="gray",     # gray edges
    width=0.5,
    alpha=0.7,
    with_labels=False      # turn on if you want node labels
)

# ZOOM IN ON THE LARGE CENTRAL CLUSTER
plt.xlim(-0.35, 0.3)   # tighter zoom horizontally
plt.ylim(-0.3, 0.35)   # tighter zoom vertically

plt.show()
